# %%
# %load_ext autoreload
# %autoreload 2

# %%
from erisk.utils import get_spark

spark = get_spark()
df = spark.read.csv(
    "gs://dsgt-clef-erisk-2024/task1/processed/baseline_nb_tfidf/v2/inference/predictions.csv",
    header=True,
    inferSchema=True,
)
df.printSchema()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/25 23:15:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/03/25 23:15:58 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# root
#  |-- symptom_number: integer (nullable = true)
#  |-- Qo: string (nullable = true)
#  |-- sentence_id: string (nullable = true)
#  |-- position_in_ranking: integer (nullable = true)
#  |-- score: double (nullable = true)
#  |-- system_name: string (nullable = true)

# %%
from pyspark.sql import functions as F

text = spark.read.parquet(
    "gs://dsgt-clef-erisk-2024/task1/parquet/tfidf/v2/data"
).select(F.col("docid").alias("sentence_id"), "text")

text_with_preds = (
    df.join(text, on="sentence_id", how="inner")
    .where("position_in_ranking < 20")
    .cache()
)

# %%
text.sample(0.01).show(n=5, truncate=False)
# Out:
# +-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |sentence_id|text                                                                                                                                                                                                                                                                                                                                                                                                             |
# +-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |217967_0_14|Roaches everywhere, burnt matches on the carpet, peanuts EVERYWHERE, interior leather scratched everywhere, looked like he spilt a soda all over the center console, paint on the seats because he does graffiti, a rattle can tossed into the back seat. I found a small nug (yes i smoked it, it was perfectly good bud). If he were to have been pulled over he would have been arrested and my car impounded.|
# |121961_3_6 |He really does not care. According to him, this is what real men do and if you don't do it then you're a homosexual. He's really closed-minded.                                                                                                                                                                                                                                                                  |
# |s_826_511_2|If you're lucky you'll get the Airdrop 4.                                                                                                                                                                                                                                                                                                                                                                        |
# |110859_0_9 |I'd met him the previous spring through a friend of ours, and we kept in touch over the summer. When we started hanging out in the fall, we hooked up one night on impulse, and then this kept happening. We started calling it a friends with benefits thing.                                                                                                                                                   |
# |44672_0_2  |\n\nI know in a lot of cases, your mother will be right. About who is right for you, what type of man is good for you, etc. Often she will be right.                                                                                                                                                                                                                                                             |
# +-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
for row in (
    text_with_preds.groupBy("symptom_number")
    .count()
    .orderBy("symptom_number")
    .collect()
):
    print(row.symptom_number)
    (
        text_with_preds.where(F.col("symptom_number") == row.symptom_number)
        .drop("Q0", "system_name")
        .where("position_in_ranking < 5")
        .orderBy("position_in_ranking")
    ).show(n=10, vertical=True, truncate=200)
# Out:
# 1
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 1
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 1
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 1
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 303770_0_6
#  symptom_number      | 1
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Even then, many jurisdictions pay little mind to that distinction. \n\nIn the criminal realm, in common law jurisdictions, "assault" is a two limbed definition. It looks like this (taken from the Q...
#
# 2
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 2
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 2
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 2
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | s_2354_215_15
#  symptom_number      | 2
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Name ----------------- Current A ------ Potenital A ------- A in our system -------- Potential A in our System Doncic ------------------ 90 ----------------- 96 ---------------------- 92 ----------...
#
# 3
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 3
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 3
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 3
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 303770_0_6
#  symptom_number      | 3
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Even then, many jurisdictions pay little mind to that distinction. \n\nIn the criminal realm, in common law jurisdictions, "assault" is a two limbed definition. It looks like this (taken from the Q...
#
# 4
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 4
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 4
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 4
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | s_2354_215_15
#  symptom_number      | 4
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Name ----------------- Current A ------ Potenital A ------- A in our system -------- Potential A in our System Doncic ------------------ 90 ----------------- 96 ---------------------- 92 ----------...
#
# 5
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 5
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 5
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 5
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | s_2354_215_15
#  symptom_number      | 5
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Name ----------------- Current A ------ Potenital A ------- A in our system -------- Potential A in our System Doncic ------------------ 90 ----------------- 96 ---------------------- 92 ----------...
#
# 6
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 6
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | s_2354_215_15
#  symptom_number      | 6
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | Name ----------------- Current A ------ Potenital A ------- A in our system -------- Potential A in our System Doncic ------------------ 90 ----------------- 96 ---------------------- 92 ----------...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | s_1262_50_1
#  symptom_number      | 6
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | SZ FLAH OLMAZ OROSPU OCUKLARI NSFW YE ATTIINIZA BAKIN AMINA KOYDUKLARIM ZERNE EMEYE EYVALLAH DEDK ZENC GTNE EYVALLAH DEDK FURRY PORNOSUNA EYVALLAH DEDK CCE PORNOSUNA EYVALLAH DEDK FUTA PORNOSUNA EY...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 144737_0_44
#  symptom_number      | 6
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | \n>\n>I checked the bottle and discovered it's main ingredient was [Sodium Hydroxide]( It's also known as caustic soda or lye. Listed [here]( are the symptoms:\n>\n>Airways and lungs\n>    Breathin...
#
# 7
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 7
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 7
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 7
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 303770_0_6
#  symptom_number      | 7
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Even then, many jurisdictions pay little mind to that distinction. \n\nIn the criminal realm, in common law jurisdictions, "assault" is a two limbed definition. It looks like this (taken from the Q...
#
# 8
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 8
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 8
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 8
# ...
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 19
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | s_2354_215_15
#  symptom_number      | 19
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Name ----------------- Current A ------ Potenital A ------- A in our system -------- Potential A in our System Doncic ------------------ 90 ----------------- 96 ---------------------- 92 ----------...
#
# 20
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 20
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 20
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 20
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | s_2354_215_15
#  symptom_number      | 20
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Name ----------------- Current A ------ Potenital A ------- A in our system -------- Potential A in our System Doncic ------------------ 90 ----------------- 96 ---------------------- 92 ----------...
#
# 21
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 174521_5_2
#  symptom_number      | 21
#  Qo                  | Q0
#  position_in_ranking | 1
#  score               | 1.0
#  text                | \n\nI hadn't used it in awhile, so I logged on to see what I actually had on it, I was for some reason friends with a teenage emo kid, she was extremely weird, like shaved side of head etc.. she wa...
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 94796_0_14
#  symptom_number      | 21
#  Qo                  | Q0
#  position_in_ranking | 2
#  score               | 1.0
#  text                | \n\n[4:52 PM, 7/21/2016] [G] Awww just left\n\n[4:52 PM, 7/21/2016] [G] And i really wanted to see u\n\n[4:52 PM, 7/21/2016] [G] Can i see u todaym\n\n[4:52 PM, 7/21/2016] [G] Please\n\n[4:53 PM, 7...
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | 516977_0_1
#  symptom_number      | 21
#  Qo                  | Q0
#  position_in_ranking | 3
#  score               | 1.0
#  text                | \n\nAnyway she eventually made it clear enough to him that it was over but he would still text and snapchat her all the time and I would let her know that made me angry but she would always tell me...
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  sentence_id         | s_2354_215_15
#  symptom_number      | 21
#  Qo                  | Q0
#  position_in_ranking | 4
#  score               | 1.0
#  text                | Name ----------------- Current A ------ Potenital A ------- A in our system -------- Potential A in our System Doncic ------------------ 90 ----------------- 96 ---------------------- 92 ----------...
